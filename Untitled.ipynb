# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('2021-04-11.csv')

# %%
data
# Out:
#      Unnamed: 0      #    Country,Other   TotalCases  NewCases TotalDeaths  \
# 0             0    NaN            World  136,128,812  +133,569   2,941,257
# 1             1    1.0              USA   31,869,996       NaN    575,595
# 2             2    2.0           Brazil   13,445,006       NaN    351,469
# 3             3    3.0            India   13,358,805    +3,340    169,305
# 4             4    4.0           France    5,023,785       NaN     98,602
# ..          ...    ...              ...          ...       ...         ...
# 207         207  214.0  Solomon Islands           19       NaN
# 208         208  215.0   Western Sahara           10       NaN          1
# 209         209  218.0            Samoa            3       NaN
# 210         210  219.0          Vanuatu            3       NaN
# 211         211  221.0            China       90,410       +10      4,636
#
#     NewDeaths TotalRecovered NewRecovered ActiveCases Serious,Critical  \
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(data['#'][190:])
