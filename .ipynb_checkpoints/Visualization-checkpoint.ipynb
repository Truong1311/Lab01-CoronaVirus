# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('2021-04-22_copy.csv', index_col=0)

# %%
data
# Out:
#              Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths  \
# 0                      USA    32551107     14637       582665        209
# 1                    India    15880534    271530       184168       1598
# 2                   Brazil    14050885         0       378530          0
# 3                   France     5339920         0       101597          0
# 4                   Russia     4727125      8271       106706        399
# ..                     ...         ...       ...          ...        ...
# 216             MS Zaandam           9         0            2          0
# 217  Saint Kitts and Nevis          44         0            0          0
# 218              Greenland          31         0            0          0
# 219       Marshall Islands           4         0            0          0
# 220             Micronesia           1         0            0          0
#
#      TotalRecovered  NewRecovered  ActiveCases  Serious,Critical  \
# ...

# %% [markdown]
# ###### Vẽ biểu đồ cho một thuộc tính ( thuộc tính Continents).
# - Dùng biểu đồ countplot để  đếm số lượng các vùng ( Continents) ở thuộc tính Continent.
# - Hàm countplot của thư viện seaborn sẽ đếm số lượng các quan sát trong thuộc tính và vẽ biểu đồ.

# %%
plt.figure(figsize=(18,10))
sns.countplot(data = data, x ='Continent')

# %% [markdown]
# ######  Biểu đồ thể hiện mối quan hệ giữa các thuộc tính TotalCases, TotalDeaths, NewCases, NewDeaths ở từng khu vực (Continents ). Từ đó có thể rút ra các nhận xét cần thiết cho việc phân tích dữ liệu và dự đoán.

# %%
fig, ax = plt.subplots(2,2,figsize = (18,10))

# Phân bố TotaCases của từng khu vực( Continents)
sns.stripplot(data = data, x = 'Continent', y ='TotalCases',ax = ax[0][0])
ax[0][0].set_title('TotalCases distribution in each Continents')
 
# Tổng số các country,other của từng khu vực( Continents)
sns.countplot(data = data, x ='Continent', ax = ax[0][1])
ax[0][1].set_title('Counts of Country,Other in each Continents')


width = 0.35


# Tổng số ca nhiễm và tử vong của từng khu vực( Continent)
ttsum_continent_cases = data.groupby(['Continent'])['TotalCases'].sum()
ttsum_continent_deaths = data.groupby(['Continent'])['TotalDeaths'].sum()

labels = ttsum_continent_cases.index
x = np.arange(len(labels))

ax[1][0].bar(x - width/2, ttsum_continent_cases.values,width,label = 'Cases')
ax[1][0].bar(x + width/2, ttsum_continent_deaths.values,width, label = 'Deaths')
ax[1][0].set_xticklabels(labels, rotation = 90)
ax[1][0].set_ylabel('Total')
ax[1][0].set_title('Total Cases and Total Deaths in Continents')
ax[1][0].set_xticks(x)


#Số ca nhiễm và tử vong của từng khu vực( Continent) trong ngày 22/4/2021
nwsum_continent_cases = data.groupby(['Continent'])['NewCases'].sum()
nwsum_continent_deaths = data.groupby(['Continent'])['NewDeaths'].sum()

ax[1][1].bar(x - width/2, nwsum_continent_cases.values,width,label = 'Cases')
ax[1][1].bar(x + width/2, nwsum_continent_deaths.values,width, label = 'Deaths')
ax[1][1].set_xticklabels(labels, rotation = 90)
ax[1][1].set_ylabel('Total')
ax[1][1].set_title('New Cases and New Deaths in Continents')
ax[1][1].set_xticks(x)

plt.legend(bbox_to_anchor = (1.2,1))
plt.show()

# %% [markdown]
# - Mối quan hệ giữa thuộc tính NewDeaths và thuộc tính Serious,Critical

# %%
plt.figure(figsize=(18,10))
#sns.distplot(data.NewDeaths.values)
#sns.distplot(data['Serious,Critical'].values)
sns.scatterplot(data = data, x= 'NewDeaths', y ='Serious,Critical', hue = 'Continent', s = 100)

# %%
plt.figure(figsize=(18,10))
sns.regplot(data = data, x= 'NewDeaths', y ='Serious,Critical')

# %%
plt.figure(figsize=(18,10))
sns.jointplot(x="NewDeaths", y="Serious,Critical", data=data)

# %%
plt.figure(figsize=(18,10))
sns.lineplot(data = data, y = 'NewCases', x = data.index, label ='NewCases')
sns.lineplot(data = data, y = 'Serious,Critical', x = data.index, label = 'Serious,Critical')
sns.lineplot(data = data, y = 'NewDeaths', x = data.index, label = 'NewDeaths')
plt.legend()

# %%
plt.figure(figsize=(18,10))
sns.regplot(data = data, y = 'NewCases', x = data.index, label ='NewCases')
sns.regplot(data = data, y = 'Serious,Critical', x = data.index, label = 'Serious,Critical')
sns.regplot(data = data, y = 'NewDeaths', x = data.index, label = 'NewDeaths')
plt.legend()

# %%
[data['NewDeaths'] > 0] or [data['Serious,Critical']>0]
# Out:
# [0       True
#  1       True
#  2      False
#  3      False
#  4       True
#         ...
#  216    False
#  217    False
#  218    False
#  219    False
#  220    False
#  Name: NewDeaths, Length: 221, dtype: bool]

# %%
df = data[data['Serious,Critical'] > 0]

# %%
plt.figure(figsize=(18,10))
sns.regplot(data = df, x= 'NewDeaths', y ='Serious,Critical')

# %%
plt.figure(figsize=(18,10))
sns.lineplot(data = df, y = 'NewDeaths', x = df.index)
sns.lineplot(data = df, y = 'Serious,Critical', x = df.index)

# %%
plt.figure(figsize=(18,10))
sns.distplot(data.NewDeaths.values)
